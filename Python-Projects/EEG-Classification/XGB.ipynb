# %%
# !pip install sklearn
# Out:
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/76/03/bb/589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import f1_score, classification_report, accuracy_score, mean_squared_error, confusion_matrix

# %%
# reading in Dataset
paths = 'http://bigdata.cs.byu.edu/Lectures/EEGEyeState.csv'
df = pd.read_table(paths,sep=',',encoding='latin1')

# split dependent and independent variables
y = df['eyeDetection']
X = df.iloc[:,:-1]

# create test and train.
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.3,random_state=40)

# %%
# XGBoost

from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train, np.ravel(y_train))

print(xgb.score(X_test, y_test))

print(sorted(zip(xgb.feature_importances_, X_test.columns), reverse=True))

print(confusion_matrix(y_test, xgb.predict(X_test)))
# Out:
# 0.7975077881619937
# [(0.1518405, 'P7'), (0.13957055, 'O1'), (0.1303681, 'F7'), (0.108895704, 'F8'), (0.0690184, 'AF4'), (0.05981595, 'T7'), (0.058282208, 'AF3'), (0.056748465, 'O2'), (0.055214725, 'FC6'), (0.04447853, 'FC5'), (0.041411042, 'F4'), (0.036809817, 'T8'), (0.030674847, 'F3'), (0.016871165, 'P8')]
# [[2144  332]
#  [ 578 1440]]
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
param = {'n_estimators': [100, 150, 250],
        'max_depth': [10, 30, 50]}

gs = GridSearchCV(xgb, param, cv=5, n_jobs=-1)
gs_fit = gs.fit(X_train, np.ravel(y_train))
pd.DataFrame(gs_fit.cv_results_).sort_values('mean_test_score', ascending=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ...

# %%
# XGBoost after tuning

xgb = XGBClassifier(n_estimators=250, max_depth=15,
                             random_state=7)
xgb.fit(X_train, np.ravel(y_train))

print("Test score:")
print(xgb.score(X_test, y_test))

print("Importances:")
print(sorted(zip(xgb.feature_importances_, X_test.columns), reverse=True))

print("Confusion Matrix:")
cmat = confusion_matrix(y_test, xgb.predict(X_test))
mats = pd.DataFrame(cmat)
print(mats)
  
print("Sensitivity")
print(mats.iloc[1,1]/( mats.iloc[1,1]+ mats.iloc[0,1]))
print("Specificity")
print(mats.iloc[0,0]/( mats.iloc[0,0]+ mats.iloc[0,1]))
# Out:
# Train score:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 1.0
# Test score:
# 0.9417000445037829
# Importances:
# [(0.09724568, 'O1'), (0.092441626, 'F7'), (0.09022885, 'F8'), (0.08030047, 'FC6'), (0.07473942, 'AF4'), (0.07235195, 'O2'), (0.06871251, 'T7'), (0.067868166, 'AF3'), (0.06518954, 'T8'), (0.06460723, 'FC5'), (0.061637454, 'F3'), (0.059453793, 'F4'), (0.05910441, 'P7'), (0.046118908, 'P8')]
# Confusion Matrix:
#       0     1
# 0  2362   114
# 1   148  1870
# Sensitivity
# ...

# %% [markdown]
# # Summary
#
# After splitting the model into train and test sets, we used scikit-learn's grid search functionality to test our XGBoost model with several different hyperparameter configurations. The best results were found using 250 trees with a max depth of 15.
#
# With these settings, we were able to acieve 94% accuracy while maintaining fairly good precision and recall.
